# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Concatenate, BatchNormalization, DepthwiseConv2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.layers import Lambda, Reshape, Layer, Activation, add
from tensorflow.keras import layers
from math import ceil
import numpy as np

# %%
class GhostModule(Layer):
  def __init__(self, out, ratio, dwkernel):
    super(GhostModule, self).__init__()
    self.ratio = ratio
    self.out = out
    self.conv_out_channel = ceil(self.out * 1.0 / ratio)    
    self.conv = Conv2D(int(self.conv_out_channel), (3, 3),
                        strides=(1, 1), padding='same', activation='relu')
    self.depthconv = DepthwiseConv2D(dwkernel, 1, padding='same',
                        depth_multiplier=ratio-1, activation='relu')
    self.concat = Concatenate()
    self.BN = BatchNormalization()

  def call(self, inputs):
    x = self.conv(inputs)
    if self.ratio == 1:
      return x
    dw = self.depthconv(x)
    dw = dw[:, :, :, :int(self.out - self.conv_out_channel)]
    output = self.BN(self.concat([x, dw]))
    return output

# %%
class GhostVGG16(Model):
  def __init__(self):
    super(GhostVGG16, self).__init__()
    self.outs = [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]       
    self.ratio = [8]*13
    self.dwkernek = [3]*13
    self.flatten = Flatten()
    self.MaxPooling = MaxPooling2D((2,2))
    self.dense1 = Dense(4096, activation='relu')
    self.dense2 = Dense(4096, activation='relu')
    self.dense3 = Dense(10, activation='softmax')    
    self.dropout = Dropout(0.5)
    for i, args in enumerate(zip(self.outs, self.ratio, self.dwkernek)):
      setattr(self, f"Gmodule{i+1}", GhostModule(*args)) 
    
  def call(self, inputs):        
    #2 x 64    
    #x = self.G_Module0(inputs)
    x = getattr(self, f"Gmodule1")(inputs) 
    x = getattr(self, f"Gmodule2")(x)
    x = self.MaxPooling(x)
    #2 x 128
    x = getattr(self, f"Gmodule3")(x) 
    x = getattr(self, f"Gmodule4")(x)
    x = self.MaxPooling(x)
    #3 x 256
    x = getattr(self, f"Gmodule5")(x) 
    x = getattr(self, f"Gmodule6")(x)    
    x = getattr(self, f"Gmodule7")(x) 
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule8")(x) 
    x = getattr(self, f"Gmodule9")(x)
    x = getattr(self, f"Gmodule10")(x)
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule11")(x)  
    x = getattr(self, f"Gmodule12")(x)
    x = getattr(self, f"Gmodule13")(x)
    x = self.MaxPooling(x)  
    #flat  
    flat = self.flatten(x)
    x = self.dense1(flat)
    x = self.dropout(x)
    x = self.dense2(x)
    x = self.dropout(x)
    #dense 10
    output = self.dense3(x)
    return output

# %%
def scheduler(epoch):
  learning_rate = 0.01
  if epoch < epoch_num * 0.4:
    return learning_rate
  if epoch < epoch_num * 0.8:
    return learning_rate * 0.1
  return learning_rate * 0.01

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
IMAGE_SIZE = 32
batch_size = 64
epoch_num = 50
AUTO = tf.data.AUTOTUNE

# %%
simple_aug = tf.keras.Sequential(
    [
        layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(factor=0.02),
        layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ]
)

# Now, map the augmentation pipeline to our training dataset
train_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

test_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
change_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
sgd = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model = GhostVGG16()
model.build(input_shape = (1, 32, 32, 3))
model.summary()
checkpoint = tf.train.Checkpoint(myModel=model)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history = model.fit(train_ds_simple,
          batch_size=batch_size,
          epochs=epoch_num,
          callbacks=[change_lr],
          validation_data=test_ds_simple)
# Out:
# Model: "ghost_vg_g16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  40970
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# ghost_module (GhostModule)   multiple                  1040
# _________________________________________________________________
# ghost_module_1 (GhostModule) multiple                  5432
# _________________________________________________________________
# ghost_module_2 (GhostModule) multiple                  10864
# _________________________________________________________________
# ghost_module_3 (GhostModule) multiple                  20080
# _________________________________________________________________
# ghost_module_4 (GhostModule) multiple                  40160
# _________________________________________________________________
# ghost_module_5 (GhostModule) multiple                  77024
# _________________________________________________________________
# ghost_module_6 (GhostModule) multiple                  77024
# _________________________________________________________________
# ghost_module_7 (GhostModule) multiple                  154048
# _________________________________________________________________
# ghost_module_8 (GhostModule) multiple                  301504
# _________________________________________________________________
# ghost_module_9 (GhostModule) multiple                  301504
# _________________________________________________________________
# ghost_module_10 (GhostModule multiple                  301504
# _________________________________________________________________
# ghost_module_11 (GhostModule multiple                  301504
# _________________________________________________________________
# ghost_module_12 (GhostModule multiple                  301504
# =================================================================
# Total params: 20,816,722
# Trainable params: 20,808,274
# Non-trainable params: 8,448
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 49s 41ms/step - loss: 1.8497 - accuracy: 0.3304 - val_loss: 1.6330 - val_accuracy: 0.4060
# Epoch 2/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.5244 - accuracy: 0.4557 - val_loss: 1.6240 - val_accuracy: 0.4376
# Epoch 3/50
# 782/782 [==============================] - 32s 40ms/step - loss: 1.3738 - accuracy: 0.5132 - val_loss: 1.3112 - val_accuracy: 0.5392
# Epoch 4/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.2411 - accuracy: 0.5640 - val_loss: 1.1728 - val_accuracy: 0.5844
# Epoch 5/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.1322 - accuracy: 0.6059 - val_loss: 1.1202 - val_accuracy: 0.6150
# Epoch 6/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.0467 - accuracy: 0.6382 - val_loss: 1.5663 - val_accuracy: 0.4951
# Epoch 7/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9807 - accuracy: 0.6648 - val_loss: 1.0016 - val_accuracy: 0.6529
# Epoch 8/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9165 - accuracy: 0.6847 - val_loss: 0.9253 - val_accuracy: 0.6887
# Epoch 9/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8680 - accuracy: 0.7054 - val_loss: 0.9606 - val_accuracy: 0.6807
# Epoch 10/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8258 - accuracy: 0.7220 - val_loss: 0.8773 - val_accuracy: 0.7030
# Epoch 11/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7925 - accuracy: 0.7323 - val_loss: 0.8239 - val_accuracy: 0.7202
# Epoch 12/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.7553 - accuracy: 0.7456 - val_loss: 0.8339 - val_accuracy: 0.7253
# Epoch 13/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7294 - accuracy: 0.7538 - val_loss: 0.8807 - val_accuracy: 0.7014
# Epoch 14/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7038 - accuracy: 0.7635 - val_loss: 0.8995 - val_accuracy: 0.6940
# Epoch 15/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6825 - accuracy: 0.7719 - val_loss: 0.8028 - val_accuracy: 0.7286
# Epoch 16/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6580 - accuracy: 0.7774 - val_loss: 0.7504 - val_accuracy: 0.7471
# Epoch 17/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6420 - accuracy: 0.7848 - val_loss: 0.7483 - val_accuracy: 0.7457
# Epoch 18/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6167 - accuracy: 0.7918 - val_loss: 0.7901 - val_accuracy: 0.7330
# Epoch 19/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6016 - accuracy: 0.7966 - val_loss: 0.6880 - val_accuracy: 0.7663
# Epoch 20/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5828 - accuracy: 0.8024 - val_loss: 0.7501 - val_accuracy: 0.7472
# Epoch 21/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5040 - accuracy: 0.8291 - val_loss: 0.6043 - val_accuracy: 0.7962
# Epoch 22/50
# 782/782 [==============================] - 33s 41ms/step - loss: 0.4718 - accuracy: 0.8416 - val_loss: 0.5914 - val_accuracy: 0.8010
# Epoch 23/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4569 - accuracy: 0.8453 - val_loss: 0.6075 - val_accuracy: 0.7924
# Epoch 24/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4566 - accuracy: 0.8472 - val_loss: 0.5870 - val_accuracy: 0.8020
# Epoch 25/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4411 - accuracy: 0.8496 - val_loss: 0.6028 - val_accuracy: 0.7935
# Epoch 26/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4278 - accuracy: 0.8544 - val_loss: 0.5898 - val_accuracy: 0.8008
# Epoch 27/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4223 - accuracy: 0.8552 - val_loss: 0.5946 - val_accuracy: 0.8016
# Epoch 28/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4198 - accuracy: 0.8579 - val_loss: 0.5882 - val_accuracy: 0.8050
# Epoch 29/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.4114 - accuracy: 0.8588 - val_loss: 0.5919 - val_accuracy: 0.8006
# Epoch 30/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4080 - accuracy: 0.8607 - val_loss: 0.5926 - val_accuracy: 0.8024
# Epoch 31/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.4028 - accuracy: 0.8635 - val_loss: 0.6015 - val_accuracy: 0.7975
# Epoch 32/50
# 782/782 [==============================] - 31s 40ms/step - loss: 0.3947 - accuracy: 0.8636 - val_loss: 0.5907 - val_accuracy: 0.8030
# Epoch 33/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3948 - accuracy: 0.8673 - val_loss: 0.5949 - val_accuracy: 0.8040
# Epoch 34/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3866 - accuracy: 0.8676 - val_loss: 0.6057 - val_accuracy: 0.7976
# Epoch 35/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3827 - accuracy: 0.8704 - val_loss: 0.5959 - val_accuracy: 0.8038
# Epoch 36/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3768 - accuracy: 0.8715 - val_loss: 0.6148 - val_accuracy: 0.7978
# Epoch 37/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3703 - accuracy: 0.8751 - val_loss: 0.6041 - val_accuracy: 0.8025
# Epoch 38/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3693 - accuracy: 0.8740 - val_loss: 0.5993 - val_accuracy: 0.8032
# Epoch 39/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3585 - accuracy: 0.8766 - val_loss: 0.6106 - val_accuracy: 0.7995
# Epoch 40/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3607 - accuracy: 0.8766 - val_loss: 0.6032 - val_accuracy: 0.8000
# Epoch 41/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3460 - accuracy: 0.8809 - val_loss: 0.6020 - val_accuracy: 0.8048
# Epoch 42/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3457 - accuracy: 0.8817 - val_loss: 0.5877 - val_accuracy: 0.8078
# Epoch 43/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3443 - accuracy: 0.8799 - val_loss: 0.5961 - val_accuracy: 0.8073
# Epoch 44/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3428 - accuracy: 0.8826 - val_loss: 0.5986 - val_accuracy: 0.8045
# Epoch 45/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3372 - accuracy: 0.8842 - val_loss: 0.5904 - val_accuracy: 0.8053
# Epoch 46/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3377 - accuracy: 0.8844 - val_loss: 0.5941 - val_accuracy: 0.8087
# Epoch 47/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3358 - accuracy: 0.8857 - val_loss: 0.5960 - val_accuracy: 0.8062
# Epoch 48/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3386 - accuracy: 0.8831 - val_loss: 0.5992 - val_accuracy: 0.8081
# Epoch 49/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3347 - accuracy: 0.8858 - val_loss: 0.5962 - val_accuracy: 0.8045
# Epoch 50/50
# 782/782 [==============================] - 32s 40ms/step - loss: 0.3353 - accuracy: 0.8861 - val_loss: 0.5930 - val_accuracy: 0.8067

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# summarize history for accuracy
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
checkpoint.save('/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/model.ckpt')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/model.ckpt-1'
