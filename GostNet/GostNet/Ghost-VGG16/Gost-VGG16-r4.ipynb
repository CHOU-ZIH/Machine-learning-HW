# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Sat Jun 19 01:10:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
  print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
  print('re-execute this cell.')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# To enable a high-RAM runtime, select the Runtime > "Change runtime type"
# menu, and then select High-RAM in the Runtime shape dropdown. Then,
# re-execute this cell.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Concatenate, BatchNormalization, DepthwiseConv2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.layers import Lambda, Reshape, Layer, Activation, add
from tensorflow.keras import layers
from math import ceil
import numpy as np

# %%
class GhostModule(Layer):
  def __init__(self, out, ratio, dwkernel):
    super(GhostModule, self).__init__()
    self.ratio = ratio
    self.out = out
    self.conv_out_channel = ceil(self.out * 1.0 / ratio)    
    self.conv = Conv2D(int(self.conv_out_channel), (3, 3),
                        strides=(1, 1), padding='same', activation='relu')
    self.depthconv = DepthwiseConv2D(dwkernel, 1, padding='same',
                        depth_multiplier=ratio-1, activation='relu')
    self.concat = Concatenate()
    self.BN = BatchNormalization()

  def call(self, inputs):
    x = self.conv(inputs)
    if self.ratio == 1:
      return x
    dw = self.depthconv(x)
    dw = dw[:, :, :, :int(self.out - self.conv_out_channel)]
    output = self.BN(self.concat([x, dw]))
    return output

# %%
class GhostVGG16(Model):
  def __init__(self):
    super(GhostVGG16, self).__init__()
    self.outs = [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]       
    self.ratio = [4]*13
    self.dwkernek = [3]*13
    self.flatten = Flatten()
    self.MaxPooling = MaxPooling2D((2,2))
    self.dense1 = Dense(4096, activation='relu')
    self.dense2 = Dense(4096, activation='relu')
    self.dense3 = Dense(10, activation='softmax')    
    self.dropout = Dropout(0.5)
    for i, args in enumerate(zip(self.outs, self.ratio, self.dwkernek)):
      setattr(self, f"Gmodule{i+1}", GhostModule(*args)) 
    
  def call(self, inputs):        
    #2 x 64    
    #x = self.G_Module0(inputs)
    x = getattr(self, f"Gmodule1")(inputs) 
    x = getattr(self, f"Gmodule2")(x)
    x = self.MaxPooling(x)
    #2 x 128
    x = getattr(self, f"Gmodule3")(x) 
    x = getattr(self, f"Gmodule4")(x)
    x = self.MaxPooling(x)
    #3 x 256
    x = getattr(self, f"Gmodule5")(x) 
    x = getattr(self, f"Gmodule6")(x)    
    x = getattr(self, f"Gmodule7")(x) 
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule8")(x) 
    x = getattr(self, f"Gmodule9")(x)
    x = getattr(self, f"Gmodule10")(x)
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule11")(x)  
    x = getattr(self, f"Gmodule12")(x)
    x = getattr(self, f"Gmodule13")(x)
    x = self.MaxPooling(x)  
    #flat  
    flat = self.flatten(x)
    x = self.dense1(flat)
    x = self.dropout(x)
    x = self.dense2(x)
    x = self.dropout(x)
    #dense 10
    output = self.dense3(x)
    return output

# %%
def scheduler(epoch):
  learning_rate = 0.01
  if epoch < epoch_num * 0.4:
    return learning_rate
  if epoch < epoch_num * 0.8:
    return learning_rate * 0.1
  return learning_rate * 0.01

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step

# %%
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
IMAGE_SIZE = 32
batch_size = 64
epoch_num = 50
AUTO = tf.data.AUTOTUNE

# %%
simple_aug = tf.keras.Sequential(
    [
        layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(factor=0.02),
        layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ]
)

# Now, map the augmentation pipeline to our training dataset
train_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

test_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
change_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
sgd = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model = GhostVGG16()
model.build(input_shape = (1, 32, 32, 3))
model.summary()
checkpoint = tf.train.Checkpoint(myModel=model)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history = model.fit(train_ds_simple,
          batch_size=batch_size,
          epochs=epoch_num,
          callbacks=[change_lr],
          validation_data=test_ds_simple)
# Out:
# Model: "ghost_vg_g16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  40970
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# ghost_module (GhostModule)   multiple                  1184
# _________________________________________________________________
# ghost_module_1 (GhostModule) multiple                  9968
# _________________________________________________________________
# ghost_module_2 (GhostModule) multiple                  19936
# _________________________________________________________________
# ghost_module_3 (GhostModule) multiple                  38368
# _________________________________________________________________
# ghost_module_4 (GhostModule) multiple                  76736
# _________________________________________________________________
# ghost_module_5 (GhostModule) multiple                  150464
# _________________________________________________________________
# ghost_module_6 (GhostModule) multiple                  150464
# _________________________________________________________________
# ghost_module_7 (GhostModule) multiple                  300928
# _________________________________________________________________
# ghost_module_8 (GhostModule) multiple                  595840
# _________________________________________________________________
# ghost_module_9 (GhostModule) multiple                  595840
# _________________________________________________________________
# ghost_module_10 (GhostModule multiple                  595840
# _________________________________________________________________
# ghost_module_11 (GhostModule multiple                  595840
# _________________________________________________________________
# ghost_module_12 (GhostModule multiple                  595840
# =================================================================
# Total params: 22,650,778
# Trainable params: 22,642,330
# Non-trainable params: 8,448
# _________________________________________________________________
# Epoch 1/50
# 782/782 [==============================] - 51s 42ms/step - loss: 1.7688 - accuracy: 0.3618 - val_loss: 1.5989 - val_accuracy: 0.4243
# Epoch 2/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.3459 - accuracy: 0.5237 - val_loss: 1.3510 - val_accuracy: 0.5386
# Epoch 3/50
# 782/782 [==============================] - 32s 41ms/step - loss: 1.1427 - accuracy: 0.6040 - val_loss: 1.3093 - val_accuracy: 0.5659
# Epoch 4/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9874 - accuracy: 0.6579 - val_loss: 0.9655 - val_accuracy: 0.6707
# Epoch 5/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8882 - accuracy: 0.6972 - val_loss: 0.8838 - val_accuracy: 0.7025
# Epoch 6/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8070 - accuracy: 0.7255 - val_loss: 0.9058 - val_accuracy: 0.6916
# Epoch 7/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7522 - accuracy: 0.7489 - val_loss: 0.8219 - val_accuracy: 0.7245
# Epoch 8/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6950 - accuracy: 0.7661 - val_loss: 0.7317 - val_accuracy: 0.7511
# Epoch 9/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6584 - accuracy: 0.7787 - val_loss: 0.7175 - val_accuracy: 0.7592
# Epoch 10/50
# 782/782 [==============================] - 33s 41ms/step - loss: 0.6171 - accuracy: 0.7940 - val_loss: 0.6851 - val_accuracy: 0.7743
# Epoch 11/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5878 - accuracy: 0.8013 - val_loss: 0.6727 - val_accuracy: 0.7746
# Epoch 12/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5545 - accuracy: 0.8125 - val_loss: 0.6670 - val_accuracy: 0.7717
# Epoch 13/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5299 - accuracy: 0.8233 - val_loss: 0.6325 - val_accuracy: 0.7847
# Epoch 14/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5074 - accuracy: 0.8322 - val_loss: 0.7158 - val_accuracy: 0.7586
# Epoch 15/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4842 - accuracy: 0.8389 - val_loss: 0.6618 - val_accuracy: 0.7748
# Epoch 16/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4625 - accuracy: 0.8462 - val_loss: 0.5767 - val_accuracy: 0.8053
# Epoch 17/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4453 - accuracy: 0.8506 - val_loss: 0.6565 - val_accuracy: 0.7789
# Epoch 18/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4270 - accuracy: 0.8570 - val_loss: 0.5885 - val_accuracy: 0.8019
# Epoch 19/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4137 - accuracy: 0.8605 - val_loss: 0.6079 - val_accuracy: 0.8027
# Epoch 20/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3988 - accuracy: 0.8650 - val_loss: 0.5524 - val_accuracy: 0.8168
# Epoch 21/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.3193 - accuracy: 0.8923 - val_loss: 0.4862 - val_accuracy: 0.8401
# Epoch 22/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.2887 - accuracy: 0.9011 - val_loss: 0.4795 - val_accuracy: 0.8399
# Epoch 23/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2699 - accuracy: 0.9074 - val_loss: 0.4795 - val_accuracy: 0.8449
# Epoch 24/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2614 - accuracy: 0.9119 - val_loss: 0.4852 - val_accuracy: 0.8417
# Epoch 25/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2560 - accuracy: 0.9130 - val_loss: 0.4718 - val_accuracy: 0.8457
# Epoch 26/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2470 - accuracy: 0.9157 - val_loss: 0.4820 - val_accuracy: 0.8432
# Epoch 27/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2380 - accuracy: 0.9192 - val_loss: 0.4842 - val_accuracy: 0.8474
# Epoch 28/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2285 - accuracy: 0.9215 - val_loss: 0.4832 - val_accuracy: 0.8454
# Epoch 29/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2229 - accuracy: 0.9232 - val_loss: 0.4827 - val_accuracy: 0.8456
# Epoch 30/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2191 - accuracy: 0.9252 - val_loss: 0.4813 - val_accuracy: 0.8471
# Epoch 31/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.2114 - accuracy: 0.9284 - val_loss: 0.4941 - val_accuracy: 0.8449
# Epoch 32/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.2096 - accuracy: 0.9290 - val_loss: 0.5018 - val_accuracy: 0.8426
# Epoch 33/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.2037 - accuracy: 0.9299 - val_loss: 0.5109 - val_accuracy: 0.8444
# Epoch 34/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1944 - accuracy: 0.9331 - val_loss: 0.4997 - val_accuracy: 0.8482
# Epoch 35/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1920 - accuracy: 0.9337 - val_loss: 0.5069 - val_accuracy: 0.8438
# Epoch 36/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1883 - accuracy: 0.9358 - val_loss: 0.5160 - val_accuracy: 0.8424
# Epoch 37/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1815 - accuracy: 0.9380 - val_loss: 0.5210 - val_accuracy: 0.8449
# Epoch 38/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1767 - accuracy: 0.9389 - val_loss: 0.5221 - val_accuracy: 0.8432
# Epoch 39/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1754 - accuracy: 0.9400 - val_loss: 0.5216 - val_accuracy: 0.8443
# Epoch 40/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1729 - accuracy: 0.9424 - val_loss: 0.5169 - val_accuracy: 0.8473
# Epoch 41/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1588 - accuracy: 0.9459 - val_loss: 0.5348 - val_accuracy: 0.8404
# Epoch 42/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1559 - accuracy: 0.9464 - val_loss: 0.5381 - val_accuracy: 0.8404
# Epoch 43/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1554 - accuracy: 0.9472 - val_loss: 0.5153 - val_accuracy: 0.8452
# Epoch 44/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1524 - accuracy: 0.9485 - val_loss: 0.5253 - val_accuracy: 0.8443
# Epoch 45/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1510 - accuracy: 0.9473 - val_loss: 0.5282 - val_accuracy: 0.8474
# Epoch 46/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1516 - accuracy: 0.9484 - val_loss: 0.5264 - val_accuracy: 0.8481
# Epoch 47/50
# 782/782 [==============================] - 33s 42ms/step - loss: 0.1501 - accuracy: 0.9501 - val_loss: 0.5214 - val_accuracy: 0.8493
# Epoch 48/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1509 - accuracy: 0.9484 - val_loss: 0.5156 - val_accuracy: 0.8479
# Epoch 49/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1490 - accuracy: 0.9493 - val_loss: 0.5257 - val_accuracy: 0.8470
# Epoch 50/50
# 782/782 [==============================] - 32s 41ms/step - loss: 0.1477 - accuracy: 0.9486 - val_loss: 0.5321 - val_accuracy: 0.8433

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# summarize history for accuracy
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
checkpoint.save('/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/Gost-VGG16-r4/model.ckpt')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/Gost-VGG16-r4/model.ckpt-1'
