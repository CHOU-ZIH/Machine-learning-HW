# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Conv2D, Concatenate, BatchNormalization, DepthwiseConv2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.layers import Lambda, Reshape, Layer, Activation, add
from tensorflow.keras import layers
from math import ceil
import numpy as np

# %%
class GhostModule(Layer):
  def __init__(self, out, ratio, dwkernel):
    super(GhostModule, self).__init__()
    self.ratio = ratio
    self.out = out
    self.conv_out_channel = ceil(self.out * 1.0 / ratio)    
    self.conv = Conv2D(int(self.conv_out_channel), (3, 3),
                        strides=(1, 1), padding='same', activation='relu')
    self.depthconv = DepthwiseConv2D(dwkernel, 1, padding='same',
                        depth_multiplier=ratio-1, activation='relu')
    self.concat = Concatenate()
    self.BN = BatchNormalization()

  def call(self, inputs):
    x = self.conv(inputs)
    if self.ratio == 1:
      return x
    dw = self.depthconv(x)
    dw = dw[:, :, :, :int(self.out - self.conv_out_channel)]
    output = self.BN(self.concat([x, dw]))
    return output

# %%
class GhostVGG16(Model):
  def __init__(self):
    super(GhostVGG16, self).__init__()
    self.outs = [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]       
    self.ratio = [16]*13
    self.dwkernek = [3]*13
    self.flatten = Flatten()
    self.MaxPooling = MaxPooling2D((2,2))
    self.dense1 = Dense(4096, activation='relu')
    self.dense2 = Dense(4096, activation='relu')
    self.dense3 = Dense(10, activation='softmax')    
    self.dropout = Dropout(0.5)
    for i, args in enumerate(zip(self.outs, self.ratio, self.dwkernek)):
      setattr(self, f"Gmodule{i+1}", GhostModule(*args)) 
    
  def call(self, inputs):        
    #2 x 64    
    #x = self.G_Module0(inputs)
    x = getattr(self, f"Gmodule1")(inputs) 
    x = getattr(self, f"Gmodule2")(x)
    x = self.MaxPooling(x)
    #2 x 128
    x = getattr(self, f"Gmodule3")(x) 
    x = getattr(self, f"Gmodule4")(x)
    x = self.MaxPooling(x)
    #3 x 256
    x = getattr(self, f"Gmodule5")(x) 
    x = getattr(self, f"Gmodule6")(x)    
    x = getattr(self, f"Gmodule7")(x) 
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule8")(x) 
    x = getattr(self, f"Gmodule9")(x)
    x = getattr(self, f"Gmodule10")(x)
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule11")(x)  
    x = getattr(self, f"Gmodule12")(x)
    x = getattr(self, f"Gmodule13")(x)
    x = self.MaxPooling(x)  
    #flat  
    flat = self.flatten(x)
    x = self.dense1(flat)
    x = self.dropout(x)
    x = self.dense2(x)
    x = self.dropout(x)
    #dense 10
    output = self.dense3(x)
    return output

# %%
def scheduler(epoch):
  learning_rate = 0.01
  if epoch < epoch_num * 0.4:
    return learning_rate
  if epoch < epoch_num * 0.8:
    return learning_rate * 0.1
  return learning_rate * 0.01

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
IMAGE_SIZE = 32
batch_size = 64
epoch_num = 70
AUTO = tf.data.AUTOTUNE

# %%
simple_aug = tf.keras.Sequential(
    [
        layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(factor=0.02),
        layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ]
)

# Now, map the augmentation pipeline to our training dataset
train_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

test_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
change_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
sgd = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9, nesterov=True)
adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model = GhostVGG16()
model.build(input_shape = (1, 32, 32, 3))
model.summary()
checkpoint = tf.train.Checkpoint(myModel=model)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history = model.fit(train_ds_simple,
          batch_size=batch_size,
          epochs=epoch_num,
          callbacks=[change_lr],
          validation_data=test_ds_simple)
# Out:
# Model: "ghost_vg_g16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  40970
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# ghost_module (GhostModule)   multiple                  968
# _________________________________________________________________
# ghost_module_1 (GhostModule) multiple                  3164
# _________________________________________________________________
# ghost_module_2 (GhostModule) multiple                  6328
# _________________________________________________________________
# ghost_module_3 (GhostModule) multiple                  10936
# _________________________________________________________________
# ghost_module_4 (GhostModule) multiple                  21872
# _________________________________________________________________
# ghost_module_5 (GhostModule) multiple                  40304
# _________________________________________________________________
# ghost_module_6 (GhostModule) multiple                  40304
# _________________________________________________________________
# ghost_module_7 (GhostModule) multiple                  80608
# _________________________________________________________________
# ghost_module_8 (GhostModule) multiple                  154336
# _________________________________________________________________
# ghost_module_9 (GhostModule) multiple                  154336
# _________________________________________________________________
# ghost_module_10 (GhostModule multiple                  154336
# _________________________________________________________________
# ghost_module_11 (GhostModule multiple                  154336
# _________________________________________________________________
# ghost_module_12 (GhostModule multiple                  154336
# =================================================================
# Total params: 19,899,694
# Trainable params: 19,891,246
# Non-trainable params: 8,448
# _________________________________________________________________
# Epoch 1/70
# 782/782 [==============================] - 51s 42ms/step - loss: 1.9398 - accuracy: 0.2910 - val_loss: 2.1375 - val_accuracy: 0.2546
# Epoch 2/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.6187 - accuracy: 0.4079 - val_loss: 1.6972 - val_accuracy: 0.3984
# Epoch 3/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.4755 - accuracy: 0.4724 - val_loss: 1.5533 - val_accuracy: 0.4421
# Epoch 4/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.3698 - accuracy: 0.5140 - val_loss: 1.4535 - val_accuracy: 0.4815
# Epoch 5/70
# 782/782 [==============================] - 32s 41ms/step - loss: 1.2883 - accuracy: 0.5429 - val_loss: 1.3804 - val_accuracy: 0.5041
# Epoch 6/70
# 782/782 [==============================] - 32s 41ms/step - loss: 1.2244 - accuracy: 0.5681 - val_loss: 1.2968 - val_accuracy: 0.5433
# Epoch 7/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.1583 - accuracy: 0.5976 - val_loss: 1.1893 - val_accuracy: 0.5910
# Epoch 8/70
# 782/782 [==============================] - 32s 41ms/step - loss: 1.1078 - accuracy: 0.6149 - val_loss: 1.2315 - val_accuracy: 0.5726
# Epoch 9/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.0699 - accuracy: 0.6311 - val_loss: 1.1325 - val_accuracy: 0.6066
# Epoch 10/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.0350 - accuracy: 0.6428 - val_loss: 1.0312 - val_accuracy: 0.6449
# Epoch 11/70
# 782/782 [==============================] - 33s 42ms/step - loss: 1.0027 - accuracy: 0.6550 - val_loss: 1.1355 - val_accuracy: 0.6106
# Epoch 12/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9735 - accuracy: 0.6674 - val_loss: 1.0423 - val_accuracy: 0.6389
# Epoch 13/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9477 - accuracy: 0.6763 - val_loss: 0.9664 - val_accuracy: 0.6736
# Epoch 14/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.9196 - accuracy: 0.6873 - val_loss: 1.0523 - val_accuracy: 0.6517
# Epoch 15/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.8974 - accuracy: 0.6945 - val_loss: 1.0144 - val_accuracy: 0.6731
# Epoch 16/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8746 - accuracy: 0.7037 - val_loss: 0.9214 - val_accuracy: 0.6896
# Epoch 17/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8551 - accuracy: 0.7095 - val_loss: 0.9745 - val_accuracy: 0.6728
# Epoch 18/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8358 - accuracy: 0.7132 - val_loss: 0.9297 - val_accuracy: 0.6868
# Epoch 19/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.8141 - accuracy: 0.7253 - val_loss: 0.9186 - val_accuracy: 0.6844
# Epoch 20/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7978 - accuracy: 0.7316 - val_loss: 0.9279 - val_accuracy: 0.6898
# Epoch 21/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7790 - accuracy: 0.7363 - val_loss: 0.8969 - val_accuracy: 0.6997
# Epoch 22/70
# 782/782 [==============================] - 33s 41ms/step - loss: 0.7634 - accuracy: 0.7381 - val_loss: 0.8473 - val_accuracy: 0.7171
# Epoch 23/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.7527 - accuracy: 0.7470 - val_loss: 0.8550 - val_accuracy: 0.7124
# Epoch 24/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7327 - accuracy: 0.7520 - val_loss: 0.7900 - val_accuracy: 0.7311
# Epoch 25/70
# 782/782 [==============================] - 32s 40ms/step - loss: 0.7236 - accuracy: 0.7537 - val_loss: 0.8760 - val_accuracy: 0.7020
# Epoch 26/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.7059 - accuracy: 0.7619 - val_loss: 0.8094 - val_accuracy: 0.7248
# Epoch 27/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6938 - accuracy: 0.7676 - val_loss: 0.8075 - val_accuracy: 0.7320
# Epoch 28/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.6840 - accuracy: 0.7690 - val_loss: 0.9077 - val_accuracy: 0.7007
# Epoch 29/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.6126 - accuracy: 0.7929 - val_loss: 0.6927 - val_accuracy: 0.7646
# Epoch 30/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5825 - accuracy: 0.8020 - val_loss: 0.6885 - val_accuracy: 0.7639
# Epoch 31/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5684 - accuracy: 0.8058 - val_loss: 0.6923 - val_accuracy: 0.7638
# Epoch 32/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5636 - accuracy: 0.8069 - val_loss: 0.6773 - val_accuracy: 0.7692
# Epoch 33/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5544 - accuracy: 0.8106 - val_loss: 0.6793 - val_accuracy: 0.7700
# Epoch 34/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5481 - accuracy: 0.8119 - val_loss: 0.6797 - val_accuracy: 0.7693
# Epoch 35/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5484 - accuracy: 0.8124 - val_loss: 0.6674 - val_accuracy: 0.7737
# Epoch 36/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5358 - accuracy: 0.8167 - val_loss: 0.6805 - val_accuracy: 0.7695
# Epoch 37/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5344 - accuracy: 0.8180 - val_loss: 0.6706 - val_accuracy: 0.7731
# Epoch 38/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5333 - accuracy: 0.8197 - val_loss: 0.6668 - val_accuracy: 0.7752
# Epoch 39/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5282 - accuracy: 0.8206 - val_loss: 0.6698 - val_accuracy: 0.7696
# Epoch 40/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5233 - accuracy: 0.8222 - val_loss: 0.6842 - val_accuracy: 0.7652
# Epoch 41/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5201 - accuracy: 0.8229 - val_loss: 0.6651 - val_accuracy: 0.7763
# Epoch 42/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5156 - accuracy: 0.8221 - val_loss: 0.6652 - val_accuracy: 0.7770
# Epoch 43/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5117 - accuracy: 0.8248 - val_loss: 0.6661 - val_accuracy: 0.7750
# Epoch 44/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5132 - accuracy: 0.8255 - val_loss: 0.6731 - val_accuracy: 0.7714
# Epoch 45/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5014 - accuracy: 0.8274 - val_loss: 0.6756 - val_accuracy: 0.7723
# Epoch 46/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.5018 - accuracy: 0.8280 - val_loss: 0.6829 - val_accuracy: 0.7680
# Epoch 47/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.5039 - accuracy: 0.8259 - val_loss: 0.6713 - val_accuracy: 0.7763
# Epoch 48/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4945 - accuracy: 0.8309 - val_loss: 0.6812 - val_accuracy: 0.7742
# Epoch 49/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4923 - accuracy: 0.8315 - val_loss: 0.6693 - val_accuracy: 0.7755
# Epoch 50/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4917 - accuracy: 0.8319 - val_loss: 0.6722 - val_accuracy: 0.7777
# Epoch 51/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4828 - accuracy: 0.8345 - val_loss: 0.6763 - val_accuracy: 0.7684
# Epoch 52/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4843 - accuracy: 0.8339 - val_loss: 0.6841 - val_accuracy: 0.7749
# Epoch 53/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4785 - accuracy: 0.8352 - val_loss: 0.6672 - val_accuracy: 0.7721
# Epoch 54/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4813 - accuracy: 0.8347 - val_loss: 0.6656 - val_accuracy: 0.7792
# Epoch 55/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4737 - accuracy: 0.8364 - val_loss: 0.6718 - val_accuracy: 0.7750
# Epoch 56/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4696 - accuracy: 0.8392 - val_loss: 0.6663 - val_accuracy: 0.7738
# Epoch 57/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4617 - accuracy: 0.8409 - val_loss: 0.6658 - val_accuracy: 0.7791
# Epoch 58/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4565 - accuracy: 0.8436 - val_loss: 0.6729 - val_accuracy: 0.7753
# Epoch 59/70
# 782/782 [==============================] - 32s 41ms/step - loss: 0.4604 - accuracy: 0.8421 - val_loss: 0.6630 - val_accuracy: 0.7767
# Epoch 60/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4560 - accuracy: 0.8440 - val_loss: 0.6689 - val_accuracy: 0.7746
# Epoch 61/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4552 - accuracy: 0.8453 - val_loss: 0.6620 - val_accuracy: 0.7783
# Epoch 62/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4522 - accuracy: 0.8442 - val_loss: 0.6684 - val_accuracy: 0.7741
# Epoch 63/70
# 782/782 [==============================] - 34s 43ms/step - loss: 0.4536 - accuracy: 0.8463 - val_loss: 0.6666 - val_accuracy: 0.7749
# Epoch 64/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4508 - accuracy: 0.8456 - val_loss: 0.6673 - val_accuracy: 0.7740
# Epoch 65/70
# 782/782 [==============================] - 34s 43ms/step - loss: 0.4530 - accuracy: 0.8436 - val_loss: 0.6695 - val_accuracy: 0.7731
# Epoch 66/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4437 - accuracy: 0.8476 - val_loss: 0.6567 - val_accuracy: 0.7799
# Epoch 67/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4465 - accuracy: 0.8458 - val_loss: 0.6680 - val_accuracy: 0.7766
# Epoch 68/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4471 - accuracy: 0.8471 - val_loss: 0.6747 - val_accuracy: 0.7768
# Epoch 69/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4470 - accuracy: 0.8470 - val_loss: 0.6661 - val_accuracy: 0.7791
# Epoch 70/70
# 782/782 [==============================] - 33s 42ms/step - loss: 0.4439 - accuracy: 0.8493 - val_loss: 0.6760 - val_accuracy: 0.7755

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# summarize history for accuracy
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
checkpoint.save('/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/Gost-VGG16-r16-70/model.ckpt')
# Out:
# '/content/drive/MyDrive/Colab Notebooks/2021/paper/gostnet/weight/Gost-VGG16-r16-70/model.ckpt-1'
