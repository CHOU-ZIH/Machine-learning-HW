# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Conv2D, concatenate, BatchNormalization, DepthwiseConv2D
from tensorflow.keras.layers import Lambda, Reshape, Layer, Activation, Add, Multiply
from tensorflow.keras import layers
from math import ceil
import numpy as np

# %%
class AE(Model):
  def __init__(self):
    super(AE, self).__init__()
    self.code = Dense(8,activation = 'relu')
  def build(self, input_shape):
    self.dense1 = Dense(input_shape[-1], activation = 'relu')
    self.dense2 = Dense(input_shape[-1], activation = 'relu')
  def call(self, inputs):    
    d1 = self.dense1(inputs)
    code = self.code(d1)
    d2 = self.dense2(code)    
    return d2

# %%
class CBAM(Model):
  def __init__(self):
    super(CBAM, self).__init__()          
    self.relu = Activation('relu') 
    self.AvgPool = AveragePooling2D(pool_size=(2, 2),strides=(1, 1), padding='same')
    self.MaxPool = MaxPooling2D(pool_size=(2, 2),strides=(1, 1), padding='same')    
    self.conv = Conv2D(1, (7, 7), strides=(1, 1), padding='same', activation='sigmoid')
    self.AE = AE()

  def call(self, inputs):
    #for channel attention    
    GAP = GlobalAveragePooling2D()(inputs)    
    GMP = GlobalMaxPooling2D()(inputs)    
    AE1 = self.AE(GAP)
    AE2 = self.AE(GMP)
    add = Add()([AE1, AE2])
    channel_attention = self.relu(add)
    multiply1 = Multiply()([inputs, channel_attention])
    #for spatial attention
    GAP_f = self.AvgPool(multiply1)
    GMP_f = self.MaxPool(multiply1)
    concat = concatenate([GAP_f, GMP_f])   
    spatial_attention = self.conv(concat)
    output = Multiply()([multiply1, spatial_attention])    
    return output

# %%
class GhostModule(Model):
  def __init__(self, out, ratio, dwkernel):
    super(GhostModule, self).__init__()
    self.ratio = ratio
    self.out = out
    self.conv_out_channel = ceil(self.out * 1.0 / ratio)    
    self.conv = Conv2D(int(self.conv_out_channel), (3, 3),
                        strides=(1, 1), padding='same', activation='relu')
    self.depthconv = DepthwiseConv2D(dwkernel, 1, padding='same',
                        depth_multiplier=ratio-1, activation='relu')
    self.BN = BatchNormalization()

  def call(self, inputs):
    x = self.conv(inputs)
    if self.ratio == 1:
      return x
    dw = self.depthconv(x)
    dw = dw[:, :, :, :int(self.out - self.conv_out_channel)]
    output = self.BN(concatenate([x, dw]))
    return output

# %%
class GhostVGG16(Model):
  def __init__(self):
    super(GhostVGG16, self).__init__()
    self.outs = [64, 64, 128, 128, 256, 256, 256, 512, 512, 512, 512, 512, 512]       
    self.ratio = [2]*13
    self.dwkernek = [3]*13
    self.flatten = Flatten()
    self.MaxPooling = MaxPooling2D((2,2))
    self.dense1 = Dense(4096, activation='relu')
    self.dense2 = Dense(4096, activation='relu')
    self.dense3 = Dense(10, activation='softmax')    
    self.dropout = Dropout(0.5)
    for i, args in enumerate(zip(self.outs, self.ratio, self.dwkernek)):
      setattr(self, f"Gmodule{i+1}", GhostModule(*args)) 
    for i in range(1):
      setattr(self, f"CBAM{i+1}", CBAM())
    
  def call(self, inputs):        
    #2 x 64    
    #x = self.G_Module0(inputs)
    x = getattr(self, f"Gmodule1")(inputs) 
    #x = getattr(self, f"CBAM1")(x)     
    x = getattr(self, f"Gmodule2")(x)
    x = self.MaxPooling(x)
    #2 x 128
    x = getattr(self, f"Gmodule3")(x) 
    #x = getattr(self, f"CBAM2")(x) 
    x = getattr(self, f"Gmodule4")(x)
    x = self.MaxPooling(x)
    #3 x 256
    x = getattr(self, f"Gmodule5")(x) 
    x = getattr(self, f"Gmodule6")(x)        
    x = getattr(self, f"Gmodule7")(x) 
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule8")(x) 
    x = getattr(self, f"Gmodule9")(x)
    x = getattr(self, f"Gmodule10")(x)
    x = self.MaxPooling(x)
    #3 x 512
    x = getattr(self, f"Gmodule11")(x)  
    x = getattr(self, f"Gmodule12")(x)
    x = getattr(self, f"CBAM1")(x) 
    x = getattr(self, f"Gmodule13")(x)
    x = self.MaxPooling(x)  
    #flat  
    flat = self.flatten(x)
    x = self.dense1(flat)
    x = self.dropout(x)
    x = self.dense2(x)
    x = self.dropout(x)
    #dense 10
    output = self.dense3(x)
    return output

# %%
def scheduler(epoch):
  learning_rate = 0.001
  if epoch < epoch_num * 0.4:
    return learning_rate
  if epoch < epoch_num * 0.8:
    return learning_rate * 0.1
  return learning_rate * 0.01

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
tf.shape(x_train)
# Out:
# <tf.Tensor: shape=(4,), dtype=int32, numpy=array([50000,    32,    32,     3], dtype=int32)>

# %%
IMAGE_SIZE = 32
batch_size = 64
epoch_num = 50
AUTO = tf.data.AUTOTUNE

# %%
simple_aug = tf.keras.Sequential(
    [
        layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
        layers.experimental.preprocessing.RandomFlip("horizontal"),
        layers.experimental.preprocessing.RandomRotation(factor=0.02),
        layers.experimental.preprocessing.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ]
)

# Now, map the augmentation pipeline to our training dataset
train_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

test_ds_simple = (
    tf.data.Dataset.from_tensor_slices((x_test, y_test))
    .shuffle(64 * 100)
    .batch(64)
    .map(lambda x, y: (simple_aug(x), y), num_parallel_calls=AUTO)
    .prefetch(AUTO)
)

# %%
#change_lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
sgd = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.09, nesterov=True)
#adam = tf.keras.optimizers.Adam(learning_rate=0.0001)

# %%
model = GhostVGG16()
model.build(input_shape = (1, 32, 32, 3))
model.summary()
# Out:
# Model: "ghost_vg_g16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            multiple                  0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dense (Dense)                multiple                  2101248
# _________________________________________________________________
# dense_1 (Dense)              multiple                  16781312
# _________________________________________________________________
# dense_2 (Dense)              multiple                  40970
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# ghost_module (GhostModule)   multiple                  1472
# _________________________________________________________________
# ghost_module_1 (GhostModule) multiple                  19040
# _________________________________________________________________
# ghost_module_2 (GhostModule) multiple                  38080
# _________________________________________________________________
# ghost_module_3 (GhostModule) multiple                  74944
# _________________________________________________________________
# ghost_module_4 (GhostModule) multiple                  149888
# _________________________________________________________________
# ghost_module_5 (GhostModule) multiple                  297344
# _________________________________________________________________
# ghost_module_6 (GhostModule) multiple                  297344
# _________________________________________________________________
# ghost_module_7 (GhostModule) multiple                  594688
# _________________________________________________________________
# ghost_module_8 (GhostModule) multiple                  1184512
# _________________________________________________________________
# ghost_module_9 (GhostModule) multiple                  1184512
# _________________________________________________________________
# ghost_module_10 (GhostModule multiple                  1184512
# _________________________________________________________________
# ghost_module_11 (GhostModule multiple                  1184512
# _________________________________________________________________
# ghost_module_12 (GhostModule multiple                  1184512
# _________________________________________________________________
# cbam (CBAM)                  multiple                  321545
# =================================================================
# Total params: 26,640,435
# Trainable params: 26,631,987
# Non-trainable params: 8,448
# _________________________________________________________________

# %% [markdown]
# !nvidia-smi

# %%
checkpoint = tf.train.Checkpoint(myModel=model)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
history = model.fit(train_ds_simple,
          batch_size=batch_size,
          epochs=100,          
          validation_data=test_ds_simple)
# Out:
# Epoch 1/100
# 782/782 [==============================] - 41s 34ms/step - loss: 2.2649 - accuracy: 0.1391 - val_loss: 2.1966 - val_accuracy: 0.1936
# Epoch 2/100
# 782/782 [==============================] - 26s 33ms/step - loss: 2.0549 - accuracy: 0.2185 - val_loss: 1.9492 - val_accuracy: 0.2656
# Epoch 3/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.8895 - accuracy: 0.2650 - val_loss: 1.8131 - val_accuracy: 0.2966
# Epoch 4/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.7866 - accuracy: 0.3081 - val_loss: 1.7808 - val_accuracy: 0.3438
# Epoch 5/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.6894 - accuracy: 0.3572 - val_loss: 1.6175 - val_accuracy: 0.3970
# Epoch 6/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.5922 - accuracy: 0.4076 - val_loss: 1.5018 - val_accuracy: 0.4500
# Epoch 7/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.4872 - accuracy: 0.4618 - val_loss: 1.4177 - val_accuracy: 0.4845
# Epoch 8/100
# 782/782 [==============================] - 26s 34ms/step - loss: 1.3997 - accuracy: 0.4943 - val_loss: 1.4074 - val_accuracy: 0.4970
# Epoch 9/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.3272 - accuracy: 0.5232 - val_loss: 1.3293 - val_accuracy: 0.5275
# Epoch 10/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.2691 - accuracy: 0.5448 - val_loss: 1.2118 - val_accuracy: 0.5707
# Epoch 11/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.2149 - accuracy: 0.5663 - val_loss: 1.1906 - val_accuracy: 0.5789
# Epoch 12/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.1692 - accuracy: 0.5854 - val_loss: 1.1962 - val_accuracy: 0.5784
# Epoch 13/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.1249 - accuracy: 0.6050 - val_loss: 1.1954 - val_accuracy: 0.5860
# Epoch 14/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.0868 - accuracy: 0.6182 - val_loss: 1.1085 - val_accuracy: 0.6144
# Epoch 15/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.0492 - accuracy: 0.6314 - val_loss: 1.0552 - val_accuracy: 0.6291
# Epoch 16/100
# 782/782 [==============================] - 26s 33ms/step - loss: 1.0157 - accuracy: 0.6436 - val_loss: 1.0582 - val_accuracy: 0.6342
# Epoch 17/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.9855 - accuracy: 0.6530 - val_loss: 1.0129 - val_accuracy: 0.6447
# Epoch 18/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.9572 - accuracy: 0.6646 - val_loss: 0.9954 - val_accuracy: 0.6545
# Epoch 19/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0
100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.2531 - accuracy: 0.9129 - val_loss: 0.8333 - val_accuracy: 0.7674
# Epoch 77/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.2430 - accuracy: 0.9163 - val_loss: 0.9270 - val_accuracy: 0.7470
# Epoch 78/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.2440 - accuracy: 0.9154 - val_loss: 0.8359 - val_accuracy: 0.7706
# Epoch 79/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.2298 - accuracy: 0.9205 - val_loss: 0.8476 - val_accuracy: 0.7711
# Epoch 80/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2280 - accuracy: 0.9225 - val_loss: 0.8783 - val_accuracy: 0.7603
# Epoch 81/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2234 - accuracy: 0.9232 - val_loss: 0.8476 - val_accuracy: 0.7741
# Epoch 82/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2226 - accuracy: 0.9230 - val_loss: 0.8478 - val_accuracy: 0.7709
# Epoch 83/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2180 - accuracy: 0.9253 - val_loss: 0.9227 - val_accuracy: 0.7561
# Epoch 84/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2131 - accuracy: 0.9257 - val_loss: 0.8545 - val_accuracy: 0.7677
# Epoch 85/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.2016 - accuracy: 0.9312 - val_loss: 0.8884 - val_accuracy: 0.7661
# Epoch 86/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.2003 - accuracy: 0.9314 - val_loss: 0.9434 - val_accuracy: 0.7519
# Epoch 87/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.1964 - accuracy: 0.9333 - val_loss: 0.9128 - val_accuracy: 0.7642
# Epoch 88/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1913 - accuracy: 0.9344 - val_loss: 0.9099 - val_accuracy: 0.7675
# Epoch 89/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.1908 - accuracy: 0.9351 - val_loss: 0.9817 - val_accuracy: 0.7504
# Epoch 90/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1871 - accuracy: 0.9350 - val_loss: 0.9557 - val_accuracy: 0.7611
# Epoch 91/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1859 - accuracy: 0.9365 - val_loss: 0.9358 - val_accuracy: 0.7678
# Epoch 92/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.1778 - accuracy: 0.9388 - val_loss: 0.9514 - val_accuracy: 0.7543
# Epoch 93/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1819 - accuracy: 0.9385 - val_loss: 0.9649 - val_accuracy: 0.7540
# Epoch 94/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1734 - accuracy: 0.9413 - val_loss: 1.0508 - val_accuracy: 0.7381
# Epoch 95/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1704 - accuracy: 0.9406 - val_loss: 0.9424 - val_accuracy: 0.7626
# Epoch 96/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1661 - accuracy: 0.9423 - val_loss: 0.9862 - val_accuracy: 0.7591
# Epoch 97/100
# 782/782 [==============================] - 27s 34ms/step - loss: 0.1558 - accuracy: 0.9466 - val_loss: 1.0164 - val_accuracy: 0.7665
# Epoch 98/100
# 782/782 [==============================] - 26s 34ms/step - loss: 0.1587 - accuracy: 0.9455 - val_loss: 0.9081 - val_accuracy: 0.7674
# Epoch 99/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1495 - accuracy: 0.9483 - val_loss: 0.9571 - val_accuracy: 0.7698
# Epoch 100/100
# 782/782 [==============================] - 26s 33ms/step - loss: 0.1534 - accuracy: 0.9473 - val_loss: 0.9445 - val_accuracy: 0.7688

# %%
model.metrics_names
# Out:
# ['loss', 'accuracy']

# %%
# summarize history for accuracy
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
checkpoint.save('/content/drive/MyDrive/Colab Notebooks/2021/paper/CBAM_GhostNet/weightmodel.ckpt')
